# %% [markdown]
# # Avocato dataset

# %% [markdown]
# ## Loading in essentials

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading in the dataset

# %%
dataset = pd.read_csv('avocado.csv')
dataset.head()

# %%
## create a statistical summary table

# %%
dataset.describe()

# %%
# check the coulmns
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
# check the data types and data structures
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8806 entries, 0 to 8805
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8806 non-null   int64
#  1   Date          8806 non-null   object
#  2   AveragePrice  8806 non-null   float64
#  3   Total Volume  8806 non-null   float64
#  4   4046          8806 non-null   float64
#  5   4225          8806 non-null   float64
#  6   4770          8806 non-null   float64
#  7   Total Bags    8806 non-null   float64
#  8   Small Bags    8805 non-null   float64
#  9   Large Bags    8805 non-null   float64
#  10  XLarge Bags   8805 non-null   float64
#  11  type          8805 non-null   object
#  12  year          8805 non-null   float64
#  13  region        8805 non-null   object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 963.3+ KB

# %%
# access a single column
dataset["Unnamed: 0"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#         ..
# 8801    11
# 8802     0
# 8803     1
# 8804     2
# 8805     3
# Name: Unnamed: 0, Length: 8806, dtype: int64

# %%
# drop a single column
dataset.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
# check the dataset
dataset.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %%
# saving a stats summary table
stats_summary = dataset.describe()
stats_summary
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   8806.000000  8.806000e+03  8.806000e+03  8.806000e+03  8.806000e+03
# mean       1.159129  1.602499e+06  5.604999e+05  5.630660e+05  4.572764e+04
# std        0.265126  4.571666e+06  1.684420e+06  1.620211e+06  1.489493e+05
# min        0.460000  3.369968e+04  7.206000e+01  1.518000e+03  0.000000e+00
# 25%        0.980000  1.964016e+05  3.071882e+04  5.095969e+04  5.289300e+02
# 50%        1.130000  4.013484e+05  1.031186e+05  1.344967e+05  6.177595e+03
# 75%        1.320000  1.017747e+06  3.571675e+05  4.126353e+05  2.187285e+04
# max        2.220000  6.103446e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  8.806000e+03  8.805000e+03  8.805000e+03    8805.000000  8805.000000
# mean   4.332052e+05  3.329706e+05  9.429914e+04    5971.613146  2016.080409
# ...

# %%
#correlatiion table
correlation_table = dataset.corr(numeric_only=True)
correlation_table
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.105552 -0.150657 -0.063742 -0.110591
# Total Volume     -0.105552      1.000000  0.975724  0.974102  0.872522
# 4046             -0.150657      0.975724  1.000000  0.922215  0.828434
# 4225             -0.063742      0.974102  0.922215  1.000000  0.884994
# 4770             -0.110591      0.872522  0.828434  0.884994  1.000000
# Total Bags       -0.085791      0.959917  0.911730  0.903198  0.795224
# Small Bags       -0.080265      0.964346  0.917320  0.913475  0.803992
# Large Bags       -0.100598      0.873555  0.826724  0.803714  0.701868
# XLarge Bags      -0.013820      0.710807  0.657024  0.655218  0.663954
# year              0.288017      0.001440 -0.017098 -0.031910 -0.052565
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.085791   -0.080265   -0.100598    -0.013820  0.288017
# ...

# %% [markdown]
# # 50_startups dataset

# %%
# load in the essential libraries
import pandas as pd
import numpy as np

# %%
#Read in the dataset with pandas and check the top 5 rows
dataset = pd.read_csv('50_startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Create a statistical summary
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#create a correlation table
correlation_table = dataset.corr()
correlation_table
# Out:
# <ipython-input-8-22e3ed6130bf>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_table = dataset.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
#Load in the visual libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(dataset['Profit'], dataset['Administration'])
plt.xlabel('profit')
plt.ylabel('Administration')
plt.title('profit and Administration')
# Out:
# Text(0.5, 1.0, 'profit and Administration')

# %%
states_marketing_spend = dataset.groupby(['State'])
states_marketing_spend_sum = states_marketing_spend.sum()
states_marketing_spend_sum
# Out:
#              R&D Spend  Administration  Marketing Spend      Profit
# State
# California  1099180.46      2052690.62       3103195.80  1766387.98
# Florida     1291584.26      1948302.36       3957176.82  1900384.39
# New York    1295316.06      2066239.00       3490882.27  1933859.59

# %%
plt.bar(states_marketing_spend_sum.index, states_marketing_spend_sum.loc[:, 'Marketing Spend'])
plt.xlabel('State')
plt.ylabel('Marketing')
plt.title('State and Marketing Spend')
# Out:
# Text(0.5, 1.0, 'State and Marketing Spend')

# %%
sns.boxplot(data=dataset, y='Profit')
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.violinplot(data=dataset, y='Profit', x='State')
# Out:
# <Axes: xlabel='State', ylabel='Profit'>

# %%
sns.histplot(dataset['Profit'])
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %%
sns.jointplot(data=dataset, x='Profit', y='Marketing Spend')

# %%
sns.pairplot(data=dataset)

# %% [markdown]
# ## Train the model

# %%
# Look at the data types
dataset.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
# Look for null values
dataset.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
# count the string categories
dataset['State'].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
# encode the string or state columns
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0  165349.20       136897.80        471784.10  192261.83              0
# 1  162597.70       151377.59        443898.53  191792.06              0
# 2  153441.51       101145.55        407934.54  191050.39              1
# 3  144372.41       118671.85        383199.62  182901.99              0
# 4  142107.34        91391.77        366168.42  166187.94              1
#
#    State_New York
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0

# %%
# Load the ML libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# check the columns
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
features = ['R&D Spend', 'Administration', 'Marketing Spend',
       'State_Florida', 'State_New York']
target = ['Profit']

# %%
# X and y
X = dataset[features]
y = dataset[target]

# %%
# Create train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# fit the data to our ML Model
lin = LinearRegression()
lin.fit(X_train, y_train)
y_pred = lin.predict(X_test)
y_pred
# Out:
# array([[133749.91948852],
#        [126771.56418161],
#        [ 97712.50105   ],
#        [ 58138.82512327],
#        [128196.53673201],
#        [192274.03929239],
#        [ 75126.75206534],
#        [127984.52000746],
#        [101453.65842151],
#        [151532.50862832]])

# %%
y_test
# Out:
#        Profit
# 10  146121.95
# 13  134307.35
# 30   99937.59
# 46   49490.75
# 18  124266.90
# 0   192261.83
# 40   78239.91
# 12  141585.52
# 29  101004.64
# 8   152211.77

# %%
# check the model performance
print("r2_score:", r2_score(y_test, y_pred))
print("mse:", mean_squared_error(y_test, y_pred))
# Out:
# r2_score: 0.9667998486975283
# mse: 50037959.16402242

# %%
dataset['Predictions'] = lin.predict(X)
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0  165349.20       136897.80        471784.10  192261.83              0
# 1  162597.70       151377.59        443898.53  191792.06              0
# 2  153441.51       101145.55        407934.54  191050.39              1
# 3  144372.41       118671.85        383199.62  182901.99              0
# 4  142107.34        91391.77        366168.42  166187.94              1
#
#    State_New York    Predictions
# 0               1  192274.039292
# 1               0  188185.066166
# 2               0  180338.371448
# 3               1  173097.905882
# 4               0  170196.772368

# %%
# save as csv
dataset.to_csv('full_dataset.csv')
